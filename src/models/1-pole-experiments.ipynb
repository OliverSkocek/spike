# %%
from Core import Pole

# %%
init = Pole(angle = 0.1, angular_velocity=-0.0, displacement=0, velocity=0.0)

# %%
init._f()
# Out:
# array([[-0.08298594,  0.0834026 ],
#        [ 0.91742865,  0.08298594]])

# %%
init._step(0)

# %%
init.rhs(0)
# Out:
# array([-8.28476978e-07,  9.15900362e-06, -8.28476978e-03,  9.15900362e-02])

# %%
init.X
# Out:
# array([ 0.00000000e+00,  1.00000000e-01, -8.28476978e-07,  9.15900362e-06])

# %%
init.run(end=100,start=0)

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.plot(init.history[0],np.array(init.history[1]))

# %%
init.X
# Out:
# array([-0.01764593,  0.32107169,  0.02695709, -0.30191986])

# %%
x=0
y=0

# %%
x=x+1e-4

# %%
y+=1e-4

# %%
x

# %%
y
